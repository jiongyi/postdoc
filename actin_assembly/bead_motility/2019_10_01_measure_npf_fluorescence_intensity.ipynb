# %%
from bead_motility2 import *
wave_folder_path = '/home/jiongyi/Documents/bead_motility/2019_10_03/exp_01'
wave_comet_props_mat = batch_analysis(wave_folder_path)
# Out:
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_03/exp_01/470_egfp_wave_pwca_550_a568_actin_640_a647_actin_1/470_egfp_wave_pwca_550_a568_actin_640_a647_actin_1_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)

# %%
n_wasp_folder_path = '/home/jiongyi/Documents/bead_motility/2019_10_03/exp_02'
n_wasp_comet_props_mat = batch_analysis(n_wasp_folder_path)

# %%
# %matplotlib inline
from matplotlib.pyplot import subplots
fig1_hand, axes1_hand = subplots()
fig1_hand.set_figwidth(7)
fig1_hand.set_figheight(5)
axes1_hand.scatter(wave_comet_props_mat[:, 0], wave_comet_props_mat[:, 1] / wave_comet_props_mat[:, 0])
axes1_hand.scatter(n_wasp_comet_props_mat[:, 0], n_wasp_comet_props_mat[:, 1] / n_wasp_comet_props_mat[:, 0])
axes1_hand.set_xlabel('Mean NPF intensity (AU)', fontsize = 12)
axes1_hand.set_ylabel('Mean Actin / NPF intensity (AU)', fontsize = 12)
axes1_hand.set_title('50 nM Arp2/3, 50 nM CP')
axes1_hand.legend({'WAVE', 'N-WASP'})

# %%
fig2_hand, axes2_hand = subplots()
fig2_hand.set_figwidth(7)
fig2_hand.set_figheight(5)
axes2_hand.scatter(wave_comet_props_mat[:, 0], wave_comet_props_mat[:, 2])
axes2_hand.scatter(n_wasp_comet_props_mat[:, 0], n_wasp_comet_props_mat[:, 2])
axes2_hand.set_xlabel('Mean NPF intensity (AU)', fontsize = 12)
axes2_hand.set_ylabel('Tail length ($\mu$m)', fontsize = 12)
axes2_hand.set_title('50 nM Arp2/3, 50 nM CP')
axes2_hand.legend({'WAVE', 'N-WASP'})

# %%
std(wave_comet_props_mat[:, 2])
# Out:
# 4.813869158152203

# %%
std(n_wasp_comet_props_mat[:, 2])
# Out:
# 4.889212433738405
