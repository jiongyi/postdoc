# %%
from bead_motility import *
# Out:
# /home/jiongyi/anaconda3/lib/python3.7/site-packages/skan/csr.py:21: NumbaDeprecationWarning: The 'numba.jitclass' decorator has moved to 'numba.experimental.jitclass' to better reflect the experimental nature of the functionality. Please update your imports to accommodate this change and see https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#change-of-jitclass-location for the time frame.
#   @numba.jitclass(csr_spec)

# %%
cp25_file_path = '/home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/25nM_cp_3min_pulse_1min_chase/comet_tail_properties.csv'
cp75_file_path = '/home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/comet_tail_properties.csv'
cp125_file_path = '/home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/125nM_cp_3min_pulse_1min_chase/comet_tail_properties.csv'
cp175_file_path = '/home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/175nM_cp_3min_pulse_1min_chase/comet_tail_properties.csv'
cp225_file_path = '/home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/225nM_cp_3min_pulse_1min_chase/comet_tail_properties.csv'

# %%
props_file_path_row = array([cp25_file_path, cp75_file_path, cp125_file_path, cp175_file_path, cp225_file_path])

# %%
plot_mean_npf_fluor(props_file_path_row)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='Capping protein (nM)', ylabel='Mean EGFP fluorescence'>)

# %%
plot_median_chase_fluor(props_file_path_row)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='Capping protein (nM)', ylabel='Median actin fluorescence'>)

# %%
plot_median_tail_length(props_file_path_row)
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='Capping protein (nM)', ylabel='Median growth rate ($\\mu$m/min)'>)

# %%
tail_length_plot_obj = box_plot_tail_length(props_file_path_row)
