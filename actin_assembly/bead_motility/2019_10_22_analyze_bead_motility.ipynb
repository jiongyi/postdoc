# %%
from bead_motility2 import *
cp25_wave_folder_path = '/home/jiongyi/Documents/bead_motility/2019_10_22/exp_01'
cp25_wave_props_mat = batch_analysis(cp25_wave_folder_path)
# Out:
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))

# %%
cp100_n_wasp_folder_path = '/home/jiongyi/Documents/bead_motility/2019_10_22/exp_02'
cp100_n_wasp_props_mat = batch_analysis(cp100_n_wasp_folder_path)
# Out:
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_22/exp_02/470_egfp_n_wasp_pwwca_550_a568_pulse_640_a647_chase_actin_2/470_egfp_n_wasp_pwwca_550_a568_pulse_640_a647_chase_actin_2_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_22/exp_02/470_egfp_n_wasp_pwwca_550_a568_pulse_640_a647_chase_actin_6/470_egfp_n_wasp_pwwca_550_a568_pulse_640_a647_chase_actin_6_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_22/exp_02/470_egfp_n_wasp_pwwca_550_a568_pulse_640_a647_chase_actin_22/470_egfp_n_wasp_pwwca_550_a568_pulse_640_a647_chase_actin_22_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_22/exp_02/470_egfp_n_wasp_pwwca_550_a568_pulse_640_a647_chase_actin_31/470_egfp_n_wasp_pwwca_550_a568_pulse_640_a647_chase_actin_31_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)

# %%
# %matplotlib inline
from matplotlib.pyplot import subplots
fig1_hand, axes1_hand = subplots()
fig1_hand.set_figwidth(7)
fig1_hand.set_figheight(5)
axes1_hand.scatter(cp25_wave_props_mat[:, 0], cp25_wave_props_mat[:, 1] / cp25_wave_props_mat[:, 0])
axes1_hand.scatter(cp100_n_wasp_props_mat[:, 0], cp100_n_wasp_props_mat[:, 1] / cp100_n_wasp_props_mat[:, 0])
axes1_hand.set_xlabel('Mean NPF intensity (AU)', fontsize = 12)
axes1_hand.set_ylabel('Mean Actin / NPF intensity (AU)', fontsize = 12)
axes1_hand.set_title('50 nM Arp2/3, 50 nM CP')
axes1_hand.legend({'WAVE', 'N-WASP'})

# %%
fig2_hand, axes2_hand = subplots()
fig2_hand.set_figwidth(7)
fig2_hand.set_figheight(5)
axes2_hand.scatter(cp25_wave_props_mat[:, 0], cp25_wave_props_mat[:, 2])
axes2_hand.scatter(cp100_n_wasp_props_mat[:, 0], cp100_n_wasp_props_mat[:, 2])
axes2_hand.set_xlabel('Mean NPF intensity (AU)', fontsize = 12)
axes2_hand.set_ylabel('Tail length ($\mu$m)', fontsize = 12)
axes2_hand.set_title('50 nM Arp2/3, 50 nM CP')
axes2_hand.legend({'WAVE', 'N-WASP'})

# %%
fig3_hand, axes3_hand = subplots()
fig3_hand.set_figwidth(7)
fig3_hand.set_figheight(5)
axes3_hand.scatter(cp25_wave_props_mat[:, 0], cp25_wave_props_mat[:, 1])
axes3_hand.tick_params(labelsize = 12)
axes3_hand.set_xlabel('Mean EGFP-WAVE PWCA intensity (A. U.)', fontsize = 12)
axes3_hand.set_ylabel('Mean A647-actin intensity (A. U.)', fontsize = 12)
# Out:
# Text(0, 0.5, 'Mean A647-actin intensity (A.U.)')

# %%
fig4_hand, axes4_hand = subplots()
fig4_hand.set_figwidth(7)
fig4_hand.set_figheight(5)
axes4_hand.scatter(cp25_wave_props_mat[:, 0], cp25_wave_props_mat[:, 2])
axes4_hand.tick_params(labelsize = 12)
axes4_hand.set_xlabel('Mean EGFP-WAVE PWCA intensity (A. U.)', fontsize = 12)
axes4_hand.set_ylabel('Tail growth rate ($\mu$m/min)', fontsize = 12)
# Out:
# Text(0, 0.5, 'Tail growth rate ($\\mu$m/min)')
