# %%
from bead_motility import *
data_folder_path_str = '/home/jiongyi/Documents/bead_motility/2019_02_19/15_min_100_nM_egfp_n_wasp_pwwca'

# %%
npf_intensity_row = measure_npf_density(data_folder_path_str)
# Out:
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/measure/_regionprops.py:250: UserWarning: regionprops and image moments (including moments, normalized moments, central moments, and inertia tensor) of 2D images will change from xy coordinates to rc coordinates in version 0.16.
# See http://scikit-image.org/docs/0.14.x/release_notes_and_installation.html#deprecations for details on how to avoid this message.
#   warn(XY_TO_RC_DEPRECATION_MESSAGE)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/measure/_regionprops.py:260: UserWarning: regionprops and image moments (including moments, normalized moments, central moments, and inertia tensor) of 2D images will change from xy coordinates to rc coordinates in version 0.16.
# See http://scikit-image.org/docs/0.14.x/release_notes_and_installation.html#deprecations for details on how to avoid this message.
#   warn(XY_TO_RC_DEPRECATION_MESSAGE)

# %%
# %matplotlib inline
from matplotlib.pyplot import hist
from numpy import mean, std
hist(npf_intensity_row)
print(str(mean(npf_intensity_row)) + ' $\pm$ ' + str(std(npf_intensity_row)))
# Out:
# 3389.4339336258868 $\pm$ 1090.307075153582

# %%
data_folder_path_str = '/home/jiongyi/Documents/bead_motility/2019_02_15/4000_nM_proII_647_actin_025_nM_arp23_025_nM_cp/100_nM_n_wasp_pwwca'
npf_intensity_row = measure_npf_density(data_folder_path_str)
hist(npf_intensity_row)
print(str(mean(npf_intensity_row)) + ' $\pm$ ' + str(std(npf_intensity_row)))
# Out:
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/measure/_regionprops.py:250: UserWarning: regionprops and image moments (including moments, normalized moments, central moments, and inertia tensor) of 2D images will change from xy coordinates to rc coordinates in version 0.16.
# See http://scikit-image.org/docs/0.14.x/release_notes_and_installation.html#deprecations for details on how to avoid this message.
#   warn(XY_TO_RC_DEPRECATION_MESSAGE)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/measure/_regionprops.py:260: UserWarning: regionprops and image moments (including moments, normalized moments, central moments, and inertia tensor) of 2D images will change from xy coordinates to rc coordinates in version 0.16.
# See http://scikit-image.org/docs/0.14.x/release_notes_and_installation.html#deprecations for details on how to avoid this message.
#   warn(XY_TO_RC_DEPRECATION_MESSAGE)
# 869.1776443846979 $\pm$ 611.4686281964352

# %%
data_folder_path_str = '/home/jiongyi/Documents/bead_motility/2019_02_15/4000_nM_proII_647_actin_100_nM_arp23_100_nM_cp/100_nM_wave_pwca'
npf_intensity_row = measure_npf_density(data_folder_path_str)
hist(npf_intensity_row)
print(str(mean(npf_intensity_row)) + ' $\pm$ ' + str(std(npf_intensity_row)))
# Out:
# 2778.748757897723 $\pm$ 941.1116954397412

# %%
data_folder_path_str = '/home/jiongyi/Documents/bead_motility/2019_02_15/4000_nM_proII_647_actin_100_nM_arp23_100_nM_cp/100_nM_n_wasp_pwwca'
npf_intensity_row = measure_npf_density(data_folder_path_str)
hist(npf_intensity_row)
print(str(mean(npf_intensity_row)) + ' $\pm$ ' + str(std(npf_intensity_row)))
# Out:
# 1159.2780218489672 $\pm$ 987.2493634338283

# %%
data_folder_path_str = '/home/jiongyi/Documents/bead_motility/2019_02_15/4000_nM_proII_647_actin_075_nM_arp23_075_nM_cp/100_nM_wave_pwca'
npf_intensity_row = measure_npf_density(data_folder_path_str)
hist(npf_intensity_row)
print(str(mean(npf_intensity_row)) + ' $\pm$ ' + str(std(npf_intensity_row)))
# Out:
# 3000.733598032224 $\pm$ 775.4710548724125

# %%
data_folder_path_str = '/home/jiongyi/Documents/bead_motility/2019_02_15/4000_nM_proII_647_actin_075_nM_arp23_075_nM_cp/100_nM_n_wasp_pwwca'
npf_intensity_row = measure_npf_density(data_folder_path_str)
hist(npf_intensity_row)
print(str(mean(npf_intensity_row)) + ' $\pm$ ' + str(std(npf_intensity_row)))
# Out:
# 527.6444135376285 $\pm$ 983.7754008703171

# %%
data_folder_path_str = '/home/jiongyi/Documents/bead_motility/2019_02_15/4000_nM_proII_647_actin_050_nM_arp23_050_nM_cp/100_nM_wave_pwca'
npf_intensity_row = measure_npf_density(data_folder_path_str)
hist(npf_intensity_row)
print(str(mean(npf_intensity_row)) + ' $\pm$ ' + str(std(npf_intensity_row)))
# Out:
# 1176.0825210363873 $\pm$ 751.6227950376036
