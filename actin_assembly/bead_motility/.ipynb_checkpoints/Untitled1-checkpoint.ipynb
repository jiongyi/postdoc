# %%
folder_path = '/home/jiongyi/Documents/mullins_lab/data/n_wasp/2021_02_03/40nM_60min_pwca/50nM_arp23_5uM_profilin_actin/25nM_cp_3min_pulse_1min_chase'

# %%
from bead_motility import *
# Out:
# /home/jiongyi/anaconda3/lib/python3.7/site-packages/skan/csr.py:21: NumbaDeprecationWarning: The 'numba.jitclass' decorator has moved to 'numba.experimental.jitclass' to better reflect the experimental nature of the functionality. Please update your imports to accommodate this change and see https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#change-of-jitclass-location for the time frame.
#   @numba.jitclass(csr_spec)

# %%
comet_tail_props_df = batch_analysis_dev(folder_path, save_segmentation = True)
# Out:
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_48/c0_egfp_c1_hilyte555_c2_alexa647_48_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_48/c0_egfp_c1_hilyte555_c2_alexa647_48_MMStack_Pos0.ome.tif
# 11.459335086136008
# 3.3513671115377135
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_13/c0_egfp_c1_hilyte555_c2_alexa647_13_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_13/c0_egfp_c1_hilyte555_c2_alexa647_13_MMStack_Pos0.ome.tif
# 12.367434329005055
# 1.5793478567077905
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_5/c0_egfp_c1_hilyte555_c2_alexa647_5_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_5/c0_egfp_c1_hilyte555_c2_alexa647_5_MMStack_Pos0.ome.tif
# 8.03411254969543
# 1.265582869379995
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_44/c0_egfp_c1_hilyte555_c2_alexa647_44_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_44/c0_egfp_c1_hilyte555_c2_alexa647_44_MMStack_Pos0.ome.tif
# 14.043128419472076
# 1.9296320804264226
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_2/c0_egfp_c1_hilyte555_c2_alexa647_2_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_2/c0_egfp_c1_hilyte555_c2_alexa647_2_MMStack_Pos0.ome.tif
# 12.789528445973566
# 2.370458760968718
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_7/c0_egfp_c1_hilyte555_c2_alexa647_7_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_7/c0_egfp_c1_hilyte555_c2_alexa647_7_MMStack_Pos0.ome.tif
# 12.475290039756347
# 2.6864248661035446
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_16/c0_egfp_c1_hilyte555_c2_alexa647_16_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_16/c0_egfp_c1_hilyte555_c2_alexa647_16_MMStack_Pos0.ome.tif
# 21.830176028802025
# 0.8173327432549179
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_25/c0_egfp_c1_hilyte555_c2_alexa647_25_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_25/c0_egfp_c1_hilyte555_c2_alexa647_25_MMStack_Pos0.ome.tif
# 8.325609256115701
# 1.348591375454748
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_31/c0_egfp_c1_hilyte555_c2_alexa647_31_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_31/c0_egfp_c1_hilyte555_c2_alexa647_31_MMStack_Pos0.ome.tif
# 11.090193359837565
# 1.9307520998459367
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_22/c0_egfp_c1_hilyte555_c2_alexa647_22_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_22/c0_egfp_c1_hilyte555_c2_alexa647_22_MMStack_Pos0.ome.tif
# 13.117240969167499
# 1.471578968745213
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_20/c0_egfp_c1_hilyte555_c2_alexa647_20_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_20/c0_egfp_c1_hilyte555_c2_alexa647_20_MMStack_Pos0.ome.tif
# 12.989402589451764
# 1.6731361900154322
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_26/c0_egfp_c1_hilyte555_c2_alexa647_26_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_26/c0_egfp_c1_hilyte555_c2_alexa647_26_MMStack_Pos0.ome.tif
# 11.609015869776654
# 1.744251536477081
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_42/c0_egfp_c1_hilyte555_c2_alexa647_42_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_42/c0_egfp_c1_hilyte555_c2_alexa647_42_MMStack_Pos0.ome.tif
# 11.743515139147194
# 1.3678970748086818
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_38/c0_egfp_c1_hilyte555_c2_alexa647_38_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_38/c0_egfp_c1_hilyte555_c2_alexa647_38_MMStack_Pos0.ome.tif
# 12.536854249492382
# 1.2920310958255419
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_43/c0_egfp_c1_hilyte555_c2_alexa647_43_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_43/c0_egfp_c1_hilyte555_c2_alexa647_43_MMStack_Pos0.ome.tif
# 12.178031739553294
# 1.1176807595643719
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_6/c0_egfp_c1_hilyte555_c2_alexa647_6_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_6/c0_egfp_c1_hilyte555_c2_alexa647_6_MMStack_Pos0.ome.tif
# 8.989402589451773
# 0.7766544044610417
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_40/c0_egfp_c1_hilyte555_c2_alexa647_40_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_40/c0_egfp_c1_hilyte555_c2_alexa647_40_MMStack_Pos0.ome.tif
# 12.29449926937055
# 1.853454916305898
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_17/c0_egfp_c1_hilyte555_c2_alexa647_17_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_17/c0_egfp_c1_hilyte555_c2_alexa647_17_MMStack_Pos0.ome.tif
# 10.424692629208108
# 0.8916451164698308
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_32/c0_egfp_c1_hilyte555_c2_alexa647_32_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_32/c0_egfp_c1_hilyte555_c2_alexa647_32_MMStack_Pos0.ome.tif
# 14.127434329005053
# 1.4621004993177191
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_41/c0_egfp_c1_hilyte555_c2_alexa647_41_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_41/c0_egfp_c1_hilyte555_c2_alexa647_41_MMStack_Pos0.ome.tif
# 13.062337649086274
# 1.6026676678642928
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_12/c0_egfp_c1_hilyte555_c2_alexa647_12_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:295: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig_hand, axes_hand = subplots()
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_12/c0_egfp_c1_hilyte555_c2_alexa647_12_MMStack_Pos0.ome.tif
# 11.52195092941116
# 0.7612350598902239
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_10/c0_egfp_c1_hilyte555_c2_alexa647_10_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_10/c0_egfp_c1_hilyte555_c2_alexa647_10_MMStack_Pos0.ome.tif
# 13.663515139147194
# 2.06277299494405
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_46/c0_egfp_c1_hilyte555_c2_alexa647_46_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_46/c0_egfp_c1_hilyte555_c2_alexa647_46_MMStack_Pos0.ome.tif
# 12.701564209736041
# 1.780651419080818
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_29/c0_egfp_c1_hilyte555_c2_alexa647_29_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_29/c0_egfp_c1_hilyte555_c2_alexa647_29_MMStack_Pos0.ome.tif
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# 11.300386719675128
# 1.5744572623895339
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_50/c0_egfp_c1_hilyte555_c2_alexa647_50_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_50/c0_egfp_c1_hilyte555_c2_alexa647_50_MMStack_Pos0.ome.tif
# 14.00430590953299
# 1.94011947697175
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_33/c0_egfp_c1_hilyte555_c2_alexa647_33_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_33/c0_egfp_c1_hilyte555_c2_alexa647_33_MMStack_Pos0.ome.tif
# 14.319595949289326
# 2.171745638025318
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_36/c0_egfp_c1_hilyte555_c2_alexa647_36_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_36/c0_egfp_c1_hilyte555_c2_alexa647_36_MMStack_Pos0.ome.tif
# 13.330193359837569
# 1.3613937700427403
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_49/c0_egfp_c1_hilyte555_c2_alexa647_49_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_49/c0_egfp_c1_hilyte555_c2_alexa647_49_MMStack_Pos0.ome.tif
# 12.587047609329936
# 2.6084846032362354
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_18/c0_egfp_c1_hilyte555_c2_alexa647_18_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_18/c0_egfp_c1_hilyte555_c2_alexa647_18_MMStack_Pos0.ome.tif
# 11.809789309126884
# 1.0289917188362343
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_30/c0_egfp_c1_hilyte555_c2_alexa647_30_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_30/c0_egfp_c1_hilyte555_c2_alexa647_30_MMStack_Pos0.ome.tif
# 11.851370849898482
# 1.9092374446384432
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_28/c0_egfp_c1_hilyte555_c2_alexa647_28_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_28/c0_egfp_c1_hilyte555_c2_alexa647_28_MMStack_Pos0.ome.tif
# 10.433060916156313
# 2.0213358718487475
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_27/c0_egfp_c1_hilyte555_c2_alexa647_27_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_27/c0_egfp_c1_hilyte555_c2_alexa647_27_MMStack_Pos0.ome.tif
# 10.869528445973568
# 2.0200087745667896
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_39/c0_egfp_c1_hilyte555_c2_alexa647_39_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_39/c0_egfp_c1_hilyte555_c2_alexa647_39_MMStack_Pos0.ome.tif
# 12.818031739553295
# 1.9243583328310407
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_8/c0_egfp_c1_hilyte555_c2_alexa647_8_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_11/c0_egfp_c1_hilyte555_c2_alexa647_11_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_11/c0_egfp_c1_hilyte555_c2_alexa647_11_MMStack_Pos0.ome.tif
# 10.975676759431465
# 0.8151523932690808
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_45/c0_egfp_c1_hilyte555_c2_alexa647_45_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_45/c0_egfp_c1_hilyte555_c2_alexa647_45_MMStack_Pos0.ome.tif
# 14.256980106014176
# 1.8459601081521537
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_15/c0_egfp_c1_hilyte555_c2_alexa647_15_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_15/c0_egfp_c1_hilyte555_c2_alexa647_15_MMStack_Pos0.ome.tif
# 7.967838379715737
# 1.3995681469699097
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_21/c0_egfp_c1_hilyte555_c2_alexa647_21_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_21/c0_egfp_c1_hilyte555_c2_alexa647_21_MMStack_Pos0.ome.tif
# 12.399595949289326
# 2.293282685406852
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_9/c0_egfp_c1_hilyte555_c2_alexa647_9_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_9/c0_egfp_c1_hilyte555_c2_alexa647_9_MMStack_Pos0.ome.tif
# 12.184692629208108
# 0.8398534486575105
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_23/c0_egfp_c1_hilyte555_c2_alexa647_23_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_23/c0_egfp_c1_hilyte555_c2_alexa647_23_MMStack_Pos0.ome.tif
# 10.792935059634512
# 1.6929838405309912
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_37/c0_egfp_c1_hilyte555_c2_alexa647_37_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_37/c0_egfp_c1_hilyte555_c2_alexa647_37_MMStack_Pos0.ome.tif
# 10.27882250993909
# 2.464321308609837
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_34/c0_egfp_c1_hilyte555_c2_alexa647_34_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_34/c0_egfp_c1_hilyte555_c2_alexa647_34_MMStack_Pos0.ome.tif
# 9.387047609329942
# 2.1643694969849183
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_3/c0_egfp_c1_hilyte555_c2_alexa647_3_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_3/c0_egfp_c1_hilyte555_c2_alexa647_3_MMStack_Pos0.ome.tif
# 6.715290039756345
# 1.4991006490251675
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_14/c0_egfp_c1_hilyte555_c2_alexa647_14_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_14/c0_egfp_c1_hilyte555_c2_alexa647_14_MMStack_Pos0.ome.tif
# 10.64901586977665
# 1.392699219938832
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_47/c0_egfp_c1_hilyte555_c2_alexa647_47_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_47/c0_egfp_c1_hilyte555_c2_alexa647_47_MMStack_Pos0.ome.tif
# 10.539209229614208
# 1.490156311646157
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_1/c0_egfp_c1_hilyte555_c2_alexa647_1_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_1/c0_egfp_c1_hilyte555_c2_alexa647_1_MMStack_Pos0.ome.tif
# 12.40430590953299
# 2.1357844129847474
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_35/c0_egfp_c1_hilyte555_c2_alexa647_35_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_35/c0_egfp_c1_hilyte555_c2_alexa647_35_MMStack_Pos0.ome.tif
# 11.263515139147191
# 1.1344739335785161
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_24/c0_egfp_c1_hilyte555_c2_alexa647_24_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_24/c0_egfp_c1_hilyte555_c2_alexa647_24_MMStack_Pos0.ome.tif
# 13.2109667991878
# 1.486640416651168
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_4/c0_egfp_c1_hilyte555_c2_alexa647_4_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_4/c0_egfp_c1_hilyte555_c2_alexa647_4_MMStack_Pos0.ome.tif
# 14.033708498984746
# 1.6661002672370488
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_19/c0_egfp_c1_hilyte555_c2_alexa647_19_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im)
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/jiongyi/Documents/mullins_lab/data/wave/2021_02_01/100nM_60min_pwca/50nM_arp23_5uM_profilin_actin/75nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_19/c0_egfp_c1_hilyte555_c2_alexa647_19_MMStack_Pos0.ome.tif
# 10.593060916156311
# 1.4425660743467192

# %%
fig_hand, axes_hand = subplots()
axes_hand.scatter(comet_tail_props_df['tail_step_quality'], comet_tail_props_df['chase_tail_length'])

# %%
print(comet_tail_props_df['chase_fluor'][comet_tail_props_df['chase_channel_name'] == 1].mean())
# Out:
# 4907.080206129143
