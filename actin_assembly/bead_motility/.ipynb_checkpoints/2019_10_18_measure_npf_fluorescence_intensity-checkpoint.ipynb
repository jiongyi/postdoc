# %%
from bead_motility2 import *

# %%
cp25_wave_folder_path = '/home/jiongyi/Documents/bead_motility/2019_10_16/exp_03'
cp25_wave_comet_props_mat = batch_analysis(cp25_wave_folder_path)
cp50_wave_folder_path = '/home/jiongyi/Documents/bead_motility/2019_10_16/exp_05'
cp50_wave_comet_props_mat = batch_analysis(cp50_wave_folder_path)
cp75_wave_folder_path = '/home/jiongyi/Documents/bead_motility/2019_10_17/exp_02'
cp75_wave_comet_props_mat = batch_analysis(cp75_wave_folder_path)
cp100_wave_folder_path = '/home/jiongyi/Documents/bead_motility/2019_10_17/exp_04'
cp100_wave_comet_props_mat = batch_analysis(cp100_wave_folder_path)
# Out:
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_3/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_3_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_11/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_11_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_1/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_1_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_5/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_5_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_24/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_24_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_7/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_7_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_29/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_29_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_25/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_25_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_9/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_9_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_2/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_2_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_23/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_23_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_19/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_19_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_16/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_16_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_18/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_18_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_20/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_20_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_13/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_13_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_30/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_30_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_15/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_15_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_27/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_27_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_6/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_6_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_8/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_8_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_22/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_22_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_21/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_21_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_14/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_14_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_04/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_17/470_egfp_wave_pwca_550_a568_pulse_640_a647_chase_actin_17_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)

# %%
# %matplotlib inline
from matplotlib.pyplot import subplots
cp_row = array([25, 50, 75, 100])
wave_mean_tail_growth_rate_row = array([mean(0.5 * cp25_wave_comet_props_mat[:, 2]),
                                        mean(0.5 * cp50_wave_comet_props_mat[:, 2]),
                                        mean(cp75_wave_comet_props_mat[:, 2]),
                                        mean(cp100_wave_comet_props_mat[:, 2])])
wave_std_tail_growth_rate_row = array([std(0.5 * cp25_wave_comet_props_mat[:, 2]),
                                        std(0.5 * cp50_wave_comet_props_mat[:, 2]),
                                        std(cp75_wave_comet_props_mat[:, 2]),
                                        std(cp100_wave_comet_props_mat[:, 2])])

n_wasp_mean_tail_growth_rate_row = array([mean(cp100_n_wasp_props_mat[:, 2])])
n_wasp_std_tail_growth_rate_row = array([std(cp100_n_wasp_props_mat[:, 2])])
print(n_wasp_mean_tail_growth_rate_row)

fig1_hand, axes1_hand = subplots()
fig1_hand.set_figheight(5)
fig1_hand.set_figwidth(7)
axes1_hand.errorbar(cp_row, wave_mean_tail_growth_rate_row, yerr = wave_std_tail_growth_rate_row, fmt = 'o-', linewidth = 3, label = 'WAVE')
axes1_hand.errorbar(cp_row[-1], n_wasp_mean_tail_growth_rate_row, yerr = n_wasp_std_tail_growth_rate_row, fmt = 'o-', linewidth = 3, label = 'N-WASP')
axes1_hand.tick_params(labelsize = 14)
axes1_hand.set_xlabel('[CP] (nM)', fontsize = 14)
axes1_hand.set_ylabel('Growth rate ($\mu$m/min)', fontsize = 14)
axes1_hand.legend(fontsize = 14)
# Out:
# [10.64]

# %%
from numpy import nanmean, nanstd
wave_mean_tail_intensity_row = array([nanmean(cp25_wave_comet_props_mat[:, 1]),
                                        nanmean(cp50_wave_comet_props_mat[:, 1]),
                                        nanmean(cp75_wave_comet_props_mat[:, 1]),
                                        nanmean(cp100_wave_comet_props_mat[:, 1])])
wave_std_tail_intensity_row = array([nanstd(cp25_wave_comet_props_mat[:, 1]),
                                        nanstd(cp50_wave_comet_props_mat[:, 1]),
                                        nanstd(cp75_wave_comet_props_mat[:, 1]),
                                        nanstd(cp100_wave_comet_props_mat[:, 1])])

n_wasp_mean_tail_intensity_row = array([nanmean(cp100_n_wasp_props_mat[:, 1])])
n_wasp_std_tail_intensity_row = array([nanstd(cp100_n_wasp_props_mat[:, 1])])

fig2_hand, axes2_hand = subplots()
fig2_hand.set_figheight(5)
fig2_hand.set_figwidth(7)
axes2_hand.errorbar(cp_row, wave_mean_tail_intensity_row, yerr = wave_std_tail_intensity_row, fmt = 'o-', linewidth = 3, label = 'WAVE')
axes2_hand.errorbar(cp_row[-1], n_wasp_mean_tail_intensity_row, yerr = n_wasp_std_tail_intensity_row, fmt = 'o-', linewidth = 3, label = 'N-WASP')
axes2_hand.tick_params(labelsize = 14)
axes2_hand.set_xlabel('[CP] (nM)', fontsize = 14)
axes2_hand.set_ylabel('Mean A647-actin intensity (AU)', fontsize = 14)
axes2_hand.legend(fontsize = 14)

# %%
wave_mean_intensity_row = array([nanmean(cp25_wave_comet_props_mat[:, 0]),
                                        nanmean(cp50_wave_comet_props_mat[:, 0]),
                                        nanmean(cp75_wave_comet_props_mat[:, 0]),
                                        nanmean(cp100_wave_comet_props_mat[:, 0])])
wave_std_intensity_row = array([nanstd(cp25_wave_comet_props_mat[:, 1]),
                                        nanstd(cp50_wave_comet_props_mat[:, 0]),
                                        nanstd(cp75_wave_comet_props_mat[:, 0]),
                                        nanstd(cp100_wave_comet_props_mat[:, 0])])

n_wasp_mean_intensity_row = array([nanmean(cp100_n_wasp_props_mat[:, 0])])
n_wasp_std_intensity_row = array([nanstd(cp100_n_wasp_props_mat[:, 0])])

fig3_hand, axes3_hand = subplots()
fig3_hand.set_figheight(5)
fig3_hand.set_figwidth(7)
axes3_hand.errorbar(cp_row, wave_mean_intensity_row, yerr = wave_std_intensity_row, fmt = 'o-', linewidth = 3, label = 'WAVE')
axes3_hand.errorbar(cp_row[-1], n_wasp_mean_intensity_row, n_wasp_std_intensity_row, fmt = 'o-', linewidth = 3, label = 'N-WASP')
axes3_hand.tick_params(labelsize = 14)
axes3_hand.set_xlabel('[CP] (nM)', fontsize = 14)
axes3_hand.set_ylabel('Mean EGFP-WAVE PWCA intensity (AU)', fontsize = 14)
axes3_hand.legend(fontsize = 14)

# %%
cp100_n_wasp_folder_path = '/home/jiongyi/Documents/bead_motility/2019_10_17/exp_05'
cp100_n_wasp_props_mat = batch_analysis(cp100_n_wasp_folder_path)
# Out:
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_05/470_egfp_n_wasp_pwwca_550_a568_pulse_640_a647_chase_actin_18/470_egfp_n_wasp_pwwca_550_a568_pulse_640_a647_chase_actin_18_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: /home/jiongyi/Documents/bead_motility/2019_10_17/exp_05/470_egfp_n_wasp_pwwca_550_a568_pulse_640_a647_chase_actin_15/470_egfp_n_wasp_pwwca_550_a568_pulse_640_a647_chase_actin_15_MMStack.ome_tail_segmentation.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
