# %%
from bead_motility3 import *

# %%
egfp_n_wasp_pwwca_folder_path = '/home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwwca'
egfp_n_wasp_pwca_folder_path = '/home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca'

egfp_n_wasp_pwwca_props_mat = batch_analysis(egfp_n_wasp_pwwca_folder_path)
egfp_n_wasp_pwca_props_mat = batch_analysis(egfp_n_wasp_pwca_folder_path)
# Out:
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwwca/egfp_hl555_widefield_11/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwwca/egfp_hl555_widefield_9/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwwca/egfp_hl555_widefield_3/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwwca/egfp_hl555_widefield_7/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwwca/egfp_hl555_widefield_16/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwwca/egfp_hl555_widefield_4/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwwca/egfp_hl555_widefield_8/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwwca/egfp_hl555_widefield_13/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwwca/egfp_hl555_widefield_1/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwwca/egfp_hl555_widefield_6/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwwca/egfp_hl555_widefield_2/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwwca/egfp_hl555_widefield_12/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwwca/egfp_hl555_widefield_5/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwwca/egfp_hl555_widefield_15/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwwca/egfp_hl555_widefield_14/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwwca/egfp_hl555_widefield_10/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca/egfp_hl555_widefield_11/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca/egfp_hl555_widefield_9/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca/egfp_hl555_widefield_19/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca/egfp_hl555_widefield_3/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca/egfp_hl555_widefield_7/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca/egfp_hl555_widefield_16/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca/egfp_hl555_widefield_4/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca/egfp_hl555_widefield_8/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca/egfp_hl555_widefield_13/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca/egfp_hl555_widefield_1/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca/egfp_hl555_widefield_6/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca/egfp_hl555_widefield_2/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca/egfp_hl555_widefield_12/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca/egfp_hl555_widefield_20/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca/egfp_hl555_widefield_18/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca/egfp_hl555_widefield_5/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca/egfp_hl555_widefield_17/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca/egfp_hl555_widefield_15/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca/egfp_hl555_widefield_14/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility3.py:63: UserWarning: /home/jiongyi/Documents/lab_data/2020_08_28/4_uM_profilin_1pct_hl555_actin_00_nM_arp23_00_nM_cp/300_nM_egfp_n_wasp_pwca/egfp_hl555_widefield_10/Pos0/img_000000000_filtered 470 GFP epi_000_npf_segmentation.tif is a low contrast image
#   imsave(file_path_str[:-4] + '_npf_segmentation.tif', img_as_uint(rgb_im))

# %%
# %matplotlib inline
from matplotlib.pyplot import subplots
import seaborn as sns
from pandas import DataFrame

egfp_intensity_dict = {'PWWCA': egfp_n_wasp_pwwca_props_mat[:, 0].flatten(), 'PWCA': egfp_n_wasp_pwca_props_mat[:, 0].flatten()}
egfp_intensity_df = DataFrame.from_dict(egfp_intensity_dict, orient = 'index')
catplot(data = egfp_intensity_df.transpose(), kind = 'swarm')

# %%
hl555_intensity_dict = {'pwwca': egfp_n_wasp_pwwca_props_mat[:, 1].flatten(), 'pwca': egfp_n_wasp_pwca_props_mat[:, 1].flatten()}
hl555_intensity_df = DataFrame.from_dict(hl555_intensity_dict, orient = 'index')
catplot(data = hl555_intensity_df.transpose(), kind = 'swarm')

# %%
fig1_hand, axes1_hand = subplots()
fig1_hand.set_figheight(6)
fig1_hand.set_figwidth(8)
axes1_hand.scatter(egfp_n_wasp_pwwca_props_mat[:, 0], egfp_n_wasp_pwwca_props_mat[:, 1], label = 'PWWCA')
axes1_hand.scatter(egfp_n_wasp_pwca_props_mat[:, 0], egfp_n_wasp_pwca_props_mat[:, 1], label = 'PWCA')
axes1_hand.set_xlim([0, 18000])
axes1_hand.set_ylim([0, 3500])
axes1_hand.legend()
axes1_hand.tick_params(labelsize=14)
axes1_hand.set_xlabel('Mean EGFP fluorescence intensity (AU)', fontsize=14)
axes1_hand.set_ylabel('Mean HL555 fluorescence itensity (AU)', fontsize=14)
# Out:
# Text(0, 0.5, 'Mean HL555 fluorescence itensity (AU)')

# %%
ratio_intensity_dict = {'PWWCA': egfp_n_wasp_pwwca_props_mat[:, 1].flatten() / egfp_n_wasp_pwwca_props_mat[:, 0].flatten(),
                        'PWCA': egfp_n_wasp_pwca_props_mat[:, 1].flatten() / egfp_n_wasp_pwca_props_mat[:, 0].flatten()}
ratio_intensity_df = DataFrame.from_dict(ratio_intensity_dict, orient = 'index')
sns.set(font_scale=1.5)
sns.catplot(data = ratio_intensity_df.transpose(), kind = 'swarm')
