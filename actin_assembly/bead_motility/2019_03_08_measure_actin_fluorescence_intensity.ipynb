# %%
from bead_motility import *
n_wasp_100_data_folder_path_str = '/home/jiongyi/Documents/bead_motility/2019_03_07/4900_nM_profilin_a568_actin_fresh_50_nM_arp23/100_nM_n_wasp_100_nM_fresh_cp'
n_wasp_200_data_folder_path_str = '/home/jiongyi/Documents/bead_motility/2019_03_07/4900_nM_profilin_a568_actin_fresh_50_nM_arp23/100_nM_n_wasp_200_nM_fresh_cp'
wave_200_data_folder_path_str = '/home/jiongyi/Documents/bead_motility/2019_03_07/4900_nM_profilin_a568_actin_fresh_50_nM_arp23/100_nM_wave_200_nM_fresh_cp'

# %%
n_wasp_100_cp_npf_au_row, n_wasp_100_cp_actin_au_row = batch_measure_actin_density(n_wasp_100_data_folder_path_str, save_images = True)
n_wasp_200_cp_npf_au_row, n_wasp_200_cp_actin_au_row = batch_measure_actin_density(n_wasp_200_data_folder_path_str, save_images = True)
wave_200_cp_npf_au_row, wave_200_cp_actin_au_row = batch_measure_actin_density(wave_200_data_folder_path_str, save_images = True)
# Out:
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/measure/_regionprops.py:250: UserWarning: regionprops and image moments (including moments, normalized moments, central moments, and inertia tensor) of 2D images will change from xy coordinates to rc coordinates in version 0.16.
# See http://scikit-image.org/docs/0.14.x/release_notes_and_installation.html#deprecations for details on how to avoid this message.
#   warn(XY_TO_RC_DEPRECATION_MESSAGE)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/measure/_regionprops.py:260: UserWarning: regionprops and image moments (including moments, normalized moments, central moments, and inertia tensor) of 2D images will change from xy coordinates to rc coordinates in version 0.16.
# See http://scikit-image.org/docs/0.14.x/release_notes_and_installation.html#deprecations for details on how to avoid this message.
#   warn(XY_TO_RC_DEPRECATION_MESSAGE)
# ...

# %%
# %matplotlib inline
from matplotlib.pyplot import figure
from seaborn import swarmplot, boxplot
from pandas import DataFrame
npf_intensity_df = DataFrame.from_dict(data = {'N-WASP 100 nM CP': n_wasp_100_cp_actin_au_row / n_wasp_100_cp_npf_au_row,
                                    'N-WASP 200 nM CP': n_wasp_200_cp_actin_au_row / n_wasp_200_cp_npf_au_row,
                                    'WAVE 200 nM CP': wave_200_cp_actin_au_row / wave_200_cp_npf_au_row}, orient = 'index')

fig_handle = figure()
fig_handle.set_figheight(8)
fig_handle.set_figwidth(10)
box_handle = boxplot(data = npf_intensity_df.transpose())
swarm_handle = swarmplot(data = npf_intensity_df.transpose(), color = "0.2")
swarm_handle.set_ylabel('Actin AU / NPF AU', fontsize = 16)
swarm_handle.tick_params(labelsize=16)
