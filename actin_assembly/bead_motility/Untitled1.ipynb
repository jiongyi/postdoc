# %%
folder_path = '/home/jiongyi/Documents/mullins_lab/data/n_wasp/2021_02_03/40nM_60min_pwca/50nM_arp23_5uM_profilin_actin/25nM_cp_3min_pulse_1min_chase'

# %%
from bead_motility import *
# Out:
# /home/jiongyi/anaconda3/lib/python3.7/site-packages/skan/csr.py:21: NumbaDeprecationWarning: The 'numba.jitclass' decorator has moved to 'numba.experimental.jitclass' to better reflect the experimental nature of the functionality. Please update your imports to accommodate this change and see https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#change-of-jitclass-location for the time frame.
#   @numba.jitclass(csr_spec)

# %%
comet_tail_props_df = batch_analysis_dev(folder_path, save_segmentation = True)
# Out:
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:401: UserWarning: /home/jiongyi/Documents/mullins_lab/data/n_wasp/2021_02_03/40nM_60min_pwca/50nM_arp23_5uM_profilin_actin/25nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_48/c0_egfp_c1_hilyte555_c2_alexa647_48_c0_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c0_segment.jpg', i_bead_overlay_im.astype('uint8'))
# /home/jiongyi/github/jupyter/actin_assembly/bead_motility/bead_motility.py:402: UserWarning: /home/jiongyi/Documents/mullins_lab/data/n_wasp/2021_02_03/40nM_60min_pwca/50nM_arp23_5uM_profilin_actin/25nM_cp_3min_pulse_1min_chase/c0_egfp_c1_hilyte555_c2_alexa647_48/c0_egfp_c1_hilyte555_c2_alexa647_48_c1_segment.jpg is a low contrast image
#   imsave(mmstack_file_path_list[i][:-21] + '_c1_segment.jpg', i_actin1_overlay_im.astype('uint8'))
# ...

# %%
fig_hand, axes_hand = subplots()
axes_hand.scatter(comet_tail_props_df['tail_step_quality'], comet_tail_props_df['chase_tail_length'])

# %%
print(comet_tail_props_df['chase_fluor'][comet_tail_props_df['chase_channel_name'] == 2].mean())
# Out:
# 18550.448294812133
