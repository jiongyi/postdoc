# %%
# %load_ext line_profiler
from gillespie_simulation import *

# %%
test_network = network(total_time = 1.0)
# %lprun -f test_network.simulate test_network.simulate()
# Out:
# 10.0
# 20.0
# 30.000000000000004
# 40.0
# 50.0
# 60.0
# 70.0
# 80.0
# 89.99999999999999
# 99.99999999999999
# 45765
# 10.15486596868795
# Timer unit: 1e-06 s
#
# Total time: 386.886 s
# File: /home/jiongyi/github/postdoc/actin_assembly/simulation/tan_mullins/gillespie_simulation.py
# Function: simulate at line 225
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    225                                               def simulate(self):
#    226         1          2.0      2.0      0.0          i_percent = 0.1
#    227         1          1.0      1.0      0.0          no_iterations = 0
#    228     45766     996862.0     21.8      0.3          while (self.current_time <= self.total_time) and (sum(~self.is_capped_row) >= 1):
#    229     45765  159651709.0   3488.5     41.3              self.calculate_transition_rates()
#    230     45765  226019318.0   4938.7     58.4              self.gillespie_step()
#    231     45765     153797.0      3.4      0.0              if self.current_time >= self.total_time * (i_percent):
#    232        10       1341.0    134.1      0.0                  print(i_percent * 100)
#    233        10         19.0      1.9      0.0                  i_percent += 0.1
#    234     45765      62731.0      1.4      0.0              no_iterations += 1
#    235         1         42.0     42.0      0.0          self.network_height = max(self.end_position_mat[:, 2])
#    236         1          2.0      2.0      0.0          self.normalized_network_growth_rate = self.network_height / (self.monomer_length * self.elongation_rate * self.current_time)
#    237         1         40.0     40.0      0.0          print(no_iterations)
#    238         1         37.0     37.0      0.0          print(self.normalized_network_growth_rate)

# %%
print(test_network.no_ends)
# Out:
# 209

# %%
fig1_hand, axes1_hand = test_network.display()
