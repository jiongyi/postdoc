# %% [markdown]
# # Implementation of nucleation model
# ### Kinetics
# #### Barbed ends
# - Elongate from monomers in solution
# - Get capped by capping protein in solution
# - Tether to empty WH2 domains
# - Dissociate from empty WH2 domains
# - Tether to WH2 domains occupied by actin monomers
# - Tethering to WH2 domains is inhibited by capping protein
# - Tether to Arp2/3 complexes bound to CA domains, allowed by capping protein
# - Barbed ends dissociate from CA-bound Arp2/3 complexes at 10 /s 97% of the time, at 1 /s 2% of the time, and then take Arp2/3 with them at 1 /s 1% of the time; daughter branches are nucleated in the last scenario
# - Tethering to Arp2/3 complex precedes tethering to WH2 domains (empty and occupied)
# - Tethering rates are proportional to the inverse squared distance to nucleation promoting factors
#
# #### Nucleation promoting factors
# - Fixed positions on the xy-plane
# - Possess WH2 and CA domains
# - WH2 domains can be occupied by actin monomers from solution
# - CA domains can be occupied by Arp2/3 complexes from solution

# %%
# %load_ext line_profiler
from nucleation import *

# %%
actin_network = Network()
actin_network.total_time = 10.0

# %%
# %lprun -f actin_network.simulate actin_network.simulate()
# Out:
# Timer unit: 1e-06 s
#
# Total time: 3181.06 s
# File: /home/jiongyi/github/postdoc/actin_assembly/simulation/tan_mullins/nucleation.py
# Function: simulate at line 325
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    325                                               def simulate(self):
#    326    201253    1255203.0      6.2      0.0          while (self.current_time < self.total_time) and (self.no_barbed > self.barbed_is_capped_row.sum()):
#    327    201252 3167810026.0  15740.5     99.6              self.gillespie_step()
#    328    201252   11756726.0     58.4      0.4              self.update_network_mechanics()
#    329    201252     234934.0      1.2      0.0              if self.no_tethered_barbed == 0:
#    330       274        996.0      3.6      0.0                  self.wh2_has_barbed_row[:] = False
#    331       274        378.0      1.4      0.0                  self.wh2_has_monomer_barbed_row[:] = False
#    332       274        412.0      1.5      0.0                  self.ca_arp23_has_barbed_row[:] = False
#    333       274       3150.0     11.5      0.0                  self.npf_xyz_mat[:, 2] = self.barbed_xyz_mat[:, 2].min()
#    334       274        183.0      0.7      0.0                  self.mean_bond_tension = 0.0
#    335       274        153.0      0.6      0.0                  self.exp_force_weight = 1.0

# %%
fig1_hand, axes1_hand = actin_network.display()

# %%
actin_network.no_barbed
# Out:
# 408

# %%
np.histogram(actin_network.barbed_xyz_mat[:, 2])
# Out:
# (array([19, 25, 29, 36, 44, 47, 44, 51, 82, 31]),
#  array([-1.3023534 , -1.14659059, -0.99082777, -0.83506495, -0.67930214,
#         -0.52353932, -0.36777651, -0.21201369, -0.05625087,  0.09951194,
#          0.25527476]))

# %%
actin_network.current_time
# Out:
# 10.000077774002266

# %%
plt.hist(180 - 180 / np.pi * np.arccos(actin_network.barbed_orientation_mat[-287:, 2]))
# Out:
# (array([ 8., 18., 18., 26., 28., 36., 38., 34., 41., 40.]),
#  array([ 0.24660713,  9.2186032 , 18.19059928, 27.16259535, 36.13459143,
#         45.1065875 , 54.07858357, 63.05057965, 72.02257572, 80.99457179,
#         89.96656787]),
#  <BarContainer object of 10 artists>)

# %%
actin_network.barbed_has_wh2_row.sum()
# Out:
# 0

# %%
actin_network.wh2_has_barbed_row.sum()
# Out:
# 0

# %%
actin_network.barbed_has_monomer_wh2_row.sum()
# Out:
# 2

# %%
actin_network.wh2_has_monomer_barbed_row.sum()
# Out:
# 2

# %%
(actin_network.barbed2npf_index_row != -1).sum()
# Out:
# 69

# %%
actin_network.barbed_has_weak_arp23_ca_row.sum()
# Out:
# 63

# %%
actin_network.barbed_has_strong_arp23_ca_row.sum()
# Out:
# 4

# %%
actin_network.barbed_has_active_arp23_ca_row.sum()
# Out:
# 0

# %%
actin_network.ca_arp23_has_barbed_row.sum()
# Out:
# 67
