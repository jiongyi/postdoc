# %%
from smith_gelles import Network

# %%
test_network = Network(total_time=20.0, cp_conc=400.0e-3)

# %%
test_network.simulate()

# %%
test_network.num_ends
# Out:
# 215

# %%
test_network.leading_edge_pos
# Out:
# 0.22995478386946694

# %%
fig1_hand, axes1_hand = test_network.display()
fig1_hand.savefig('figures/200-nM-capping-protein.png', dpi=600)

# %%
test_network.plot_orientation()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fef4d9bb748>)

# %%
test_network.leading_edge_pos / test_network.current_time / (test_network.elongation_rate * test_network.monomer_width)
# Out:
# 0.07742585315469701

# %%
print(test_network.num_tethering_events)
# Out:
# 9161

# %%
print(test_network.num_untethering_events)
# Out:
# 9143

# %%
print((test_network.WH2_state_row == 1).sum())
# Out:
# 887
