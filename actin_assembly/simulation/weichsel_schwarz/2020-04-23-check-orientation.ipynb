# %%
from weichsel_schwarz import Network

# %%
test_network = Network(capping_rate_const=4.0)

# %%
test_network.simulate()

# %%
fig1_hand, axes1_hand = test_network.display()

# %%
test_network.plot_orientation()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f9a2468fa90>)

# %%
test_network.compute_order_parameter()
print(test_network.order_parameter)
# Out:
# -1.0
