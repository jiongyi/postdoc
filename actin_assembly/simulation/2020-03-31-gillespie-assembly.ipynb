# %%
# %load_ext line_profiler
from gillespie_simulation import *

# %%
test_network = network(total_time = 1.0)
# %lprun -f test_network.simulate test_network.simulate()
# Out:
# 10.0
# 20.0
# 30.000000000000004
# 40.0
# 50.0
# 60.0
# 70.0
# 80.0
# 89.99999999999999
# 99.99999999999999
# 47445
# 9.14183070988821
# Timer unit: 1e-06 s
#
# Total time: 355.323 s
# File: /home/jiongyi/github/jupyter/actin_assembly/simulation/gillespie_simulation.py
# Function: simulate at line 225
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    225                                               def simulate(self):
#    226         1          3.0      3.0      0.0          i_percent = 0.1
#    227         1          1.0      1.0      0.0          no_iterations = 0
#    228     47446     858065.0     18.1      0.2          while (self.current_time <= self.total_time) and (sum(~self.is_capped_row) >= 1):
#    229     47445  141822909.0   2989.2     39.9              self.calculate_transition_rates()
#    230     47445  212461241.0   4478.1     59.8              self.gillespie_step()
#    231     47445     126918.0      2.7      0.0              if self.current_time >= self.total_time * (i_percent):
#    232        10       1123.0    112.3      0.0                  print(i_percent * 100)
#    233        10         15.0      1.5      0.0                  i_percent += 0.1
#    234     47445      52468.0      1.1      0.0              no_iterations += 1
#    235         1         51.0     51.0      0.0          self.network_height = max(self.end_position_mat[:, 2])
#    236         1          3.0      3.0      0.0          self.normalized_network_growth_rate = self.network_height / (self.monomer_length * self.elongation_rate * self.current_time)
#    237         1         49.0     49.0      0.0          print(no_iterations)
#    238         1         48.0     48.0      0.0          print(self.normalized_network_growth_rate)

# %%
print(test_network.no_ends)
# Out:
# 214

# %%
fig1_hand, axes1_hand = test_network.display()
fig1_hand.savefig('network-polymerase.png', dpi=600)
