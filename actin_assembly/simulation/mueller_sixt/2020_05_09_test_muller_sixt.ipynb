# %%
from mueller_sixt import Network

# %%
test_network = Network()

# %%
test_network.simulate()

# %%
test_network.display()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f87b73edc88>)

# %%
test_network.plot_orientation()
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f87b4c9a080>)

# %%
test_network.current_time
# Out:
# 20.00000000000146
