# %%
from tethered_gated_weichsel_schwarz import *

# %%
actin_network = network()
actin_network.cap_rate_const *= 5e-1
actin_network.time_interval = 1e-2
actin_network.simulate()

# %%
print(actin_network.no_filaments)
# Out:
# 278

# %%
print(actin_network.x_leading / actin_network.time * 6e-2)
# Out:
# 2.903709232557689

# %%
# %matplotlib inline
fig_hand, axes_hand = actin_network.plot_network()

# %%
actin_network.time
# Out:
# 60.00999999999663

# %%
fig2, axes2_hand = actin_network.plot_alpha_distribution()

# %%
actin_network.compute_alpha_order()
print(actin_network.alpha_order_param)
# Out:
# -0.5555555555555556
