# %%
# %load_ext line_profiler
from gillespie_simulation import *

# %%
test_network = network(total_time = 1.0)
# %lprun -f test_network.simulate test_network.simulate()
# Out:
# 10.0
# 20.0
# 30.000000000000004
# 40.0
# 50.0
# 60.0
# 70.0
# 80.0
# 89.99999999999999
# 99.99999999999999
# 45640
# 8.642514566830759
# Timer unit: 1e-06 s
#
# Total time: 330.85 s
# File: /home/jiongyi/github/jupyter/actin_assembly/simulation/gillespie_simulation.py
# Function: simulate at line 225
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    225                                               def simulate(self):
#    226         1          2.0      2.0      0.0          i_percent = 0.1
#    227         1          1.0      1.0      0.0          no_iterations = 0
#    228     45641     834818.0     18.3      0.3          while (self.current_time <= self.total_time) and (sum(~self.is_capped_row) >= 1):
#    229     45640  131262101.0   2876.0     39.7              self.calculate_transition_rates()
#    230     45640  198577034.0   4350.9     60.0              self.gillespie_step()
#    231     45640     124643.0      2.7      0.0              if self.current_time >= self.total_time * (i_percent):
#    232        10       1042.0    104.2      0.0                  print(i_percent * 100)
#    233        10         12.0      1.2      0.0                  i_percent += 0.1
#    234     45640      50347.0      1.1      0.0              no_iterations += 1
#    235         1         33.0     33.0      0.0          self.network_height = max(self.end_position_mat[:, 2])
#    236         1          2.0      2.0      0.0          self.normalized_network_growth_rate = self.network_height / (self.monomer_length * self.elongation_rate * self.current_time)
#    237         1         32.0     32.0      0.0          print(no_iterations)
#    238         1         29.0     29.0      0.0          print(self.normalized_network_growth_rate)

# %%
print(test_network.no_ends)
# Out:
# 211

# %%
fig1_hand, axes1_handtest_network.display()
fig1_hand.savefig('network-polymerase.png', dpi=600)
