# %%
from numpy import arange, hstack, log, array, full, cumsum, searchsorted, delete, unravel_index, logical_and, zeros, exp
from numpy.random import rand, choice
# %load_ext line_profiler
def simulate_polymerase():
    end_position = 0
    no_domains = round(1.0 / (2.7e-3))
    has_npf_row = zeros(no_domains, dtype = bool)
    has_npf_row[arange(0, no_domains, 5)] = True
    has_monomer_row = zeros(no_domains, dtype = bool)
    monomer_count_row = zeros(no_domains, dtype = int)

    actin_conc = 5.0
    elongation_rate = 11 * actin_conc
    loading_rate = 5.0 * actin_conc * (42 / (42 + 8))**(1/3)
    unloading_rate = 3.0
    actin_diff_rate = 1.0 / (2.7e-3)**2

    current_time = 0.0
    total_time = 1.0

    transition_state_mat = zeros((4, no_domains))
    while current_time <= total_time and end_position <= no_domains:
        # Generate transition rate matrix.
        # Actin loading.
        transition_state_mat[0, logical_and(has_npf_row, ~has_monomer_row)] = loading_rate
        # Actin unloading.
        transition_state_mat[1, logical_and(has_npf_row, has_monomer_row)] = unloading_rate
        # Forward diffusion.
        transition_state_mat[2, :] = actin_diff_rate * monomer_count_row
        # Backward diffusion
        transition_state_mat[3, :] = actin_diff_rate * monomer_count_row
        total_rate = transition_state_mat.sum()
        probability_row = transition_state_mat.flatten() / total_rate
        index_transition = choice(probability_row.size, p = probability_row)
        transition_row, transition_col = unravel_index(index_transition, transition_state_mat.shape)
        if transition_row == 0:
            has_monomer_row[transition_col] = True
        elif transition_row == 1:
            has_monomer_row[transition_col] = False
            monomer_count_row[transition_col] += 1
        elif transition_row == 2:
            monomer_count_row[transition_col] -= 1
            if transition_col < (no_domains - 1):
                monomer_count_row[transition_col + 1] += 1
        elif transition_row == 3:
            monomer_count_row[transition_col] -= 1
            if transition_col > 0:
                monomer_count_row[transition_col - 1] += 1
        time_interval = -log(rand()) / total_rate
        current_time += time_interval
        if monomer_count_row[end_position + 1] > 0:
            monomer_count_row[end_position + 1] -= 1
            end_position += 1
        if exp(-elongation_rate * time_interval) < rand():
            end_position += 1
    print(end_position / current_time)
    return end_position / current_time

# %%
# %lprun -f simulate_polymerase simulate_polymerase()
# Out:
# 104.99866670030268
# Timer unit: 1e-06 s
#
# Total time: 266.523 s
# File: <ipython-input-6-8cb21a789d22>
# Function: simulate_polymerase at line 4
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      4                                           def simulate_polymerase():
#      5         1          8.0      8.0      0.0      end_position = 0
#      6         1         11.0     11.0      0.0      no_domains = round(1.0 / (2.7e-3))
#      7         1         27.0     27.0      0.0      has_npf_row = zeros(no_domains, dtype = bool)
#      8         1         56.0     56.0      0.0      has_npf_row[arange(0, no_domains, 10)] = True
#      9         1         12.0     12.0      0.0      has_monomer_row = zeros(no_domains, dtype = bool)
#     10         1         21.0     21.0      0.0      monomer_count_row = zeros(no_domains, dtype = int)
#     11
#     12         1          4.0      4.0      0.0      actin_conc = 5.0
#     13         1          6.0      6.0      0.0      elongation_rate = 11 * actin_conc
#     14         1          5.0      5.0      0.0      loading_rate = 5.0 * actin_conc * (42 / (42 + 8))**(1/3)
#     15         1          4.0      4.0      0.0      unloading_rate = 3.0
#     16         1          4.0      4.0      0.0      actin_diff_rate = 1.0 / (2.7e-3)**2
#     17
#     18         1          4.0      4.0      0.0      current_time = 0.0
#     19         1          4.0      4.0      0.0      total_time = 1.0
#     20
#     21         1         22.0     22.0      0.0      transition_state_mat = zeros((4, no_domains))
#     22   1490742    3077087.0      2.1      1.2      while current_time <= total_time and end_position <= no_domains:
#     23                                                   # Generate transition rate matrix.
#     24                                                   # Actin loading.
#     25   1490741   15844382.0     10.6      5.9          transition_state_mat[0, logical_and(has_npf_row, ~has_monomer_row)] = loading_rate
#     26                                                   # Actin unloading.
#     27   1490741    9991873.0      6.7      3.7          transition_state_mat[1, logical_and(has_npf_row, has_monomer_row)] = unloading_rate
#     28                                                   # Forward diffusion.
#     29   1490741   11985441.0      8.0      4.5          transition_state_mat[2, :] = actin_diff_rate * monomer_count_row
#     30                                                   # Backward diffusion
#     31   1490741    8346149.0      5.6      3.1          transition_state_mat[3, :] = actin_diff_rate * monomer_count_row
#     32   1490741   17917207.0     12.0      6.7          total_rate = transition_state_mat.sum()
#     33   1490741   15004479.0     10.1      5.6          probability_row = transition_state_mat.flatten() / total_rate
#     34   1490741  116355556.0     78.1     43.7          index_transition = choice(probability_row.size, p = probability_row)
#     35   1490741   16757249.0     11.2      6.3          transition_row, transition_col = unravel_index(index_transition, transition_state_mat.shape)
#     36   1490741    3709488.0      2.5      1.4          if transition_row == 0:
#     37       887       2636.0      3.0      0.0              has_monomer_row[transition_col] = True
#     38   1489854    2819843.0      1.9      1.1          elif transition_row == 1:
#     39       100        286.0      2.9      0.0              has_monomer_row[transition_col] = False
#     40       100        353.0      3.5      0.0              monomer_count_row[transition_col] += 1
#     41   1489754    2763517.0      1.9      1.0          elif transition_row == 2:
#     42    745552    2709793.0      3.6      1.0              monomer_count_row[transition_col] -= 1
#     43    745552    1586584.0      2.1      0.6              if transition_col < (no_domains - 1):
#     44    745507    2499031.0      3.4      0.9                  monomer_count_row[transition_col + 1] += 1
#     45    744202    1398529.0      1.9      0.5          elif transition_row == 3:
#     46    744202    2711830.0      3.6      1.0              monomer_count_row[transition_col] -= 1
#     47    744202    1429757.0      1.9      0.5              if transition_col > 0:
#     48    744196    2467314.0      3.3      0.9                  monomer_count_row[transition_col - 1] += 1
#     49   1490741   10369999.0      7.0      3.9          time_interval = -log(rand()) / total_rate
#     50   1490741    2919093.0      2.0      1.1          current_time += time_interval
#     51   1490741    3784258.0      2.5      1.4          if monomer_count_row[end_position + 1] > 0:
#     52        48        117.0      2.4      0.0              monomer_count_row[end_position + 1] -= 1
#     53        48         81.0      1.7      0.0              end_position += 1
#     54   1490741   10070321.0      6.8      3.8          if exp(-elongation_rate * time_interval) < rand():
#     55        57        109.0      1.9      0.0              end_position += 1
#     56         1        135.0    135.0      0.0      print(end_position / current_time)
#     57         1          2.0      2.0      0.0      return end_position / current_time
