# %% [markdown]
# # A linear polymerase
#
# ## Setup
#
# - A micron-long domain divided up into 37~ subdomains the width of an actin monomer (2.7 nm)
# - A barbed end starting in the first subdomain
# - An NPF every 10 subdomains
# - A solution elongation rate constant equal to $11\ \mathrm{\mu M^{-1} s^{-1}}$
# - An actin loading rate constant equal to $5.0\ \mathrm{\mu M^{-1} s^{-1}}$. The constant gets corrected by a factor that is the cubic root of the molecular-weight ratio.
# - A dissociation rate constant equal to $3.0\ \mathrm{s^{-1}}$
# - A monomer diffusion coefficient equal to $1.0\ \mathrm{\mu m^2 s^{-1}}$
# - A Gillespie algorithm to simulate barbed-end elongation and explicit of monomers unbinding from NPF sites

# %%
from numpy import arange, hstack, log, array, full, cumsum, searchsorted, delete, unravel_index, logical_and, zeros, exp
from numpy.random import rand, choice
# %load_ext line_profiler
def simulate_polymerase():
    end_position = 0
    no_domains = round(1.0 / (2.7e-3))
    has_npf_row = zeros(no_domains, dtype = bool)
    has_npf_row[arange(0, no_domains, 10)] = True
    has_monomer_row = zeros(no_domains, dtype = bool)
    monomer_count_row = zeros(no_domains, dtype = int)

    actin_conc = 2.0
    elongation_rate = 11 * actin_conc
    loading_rate = 5.0 * actin_conc * (42 / (42 + 8))**(1/3)
    unloading_rate = 3.0
    actin_diff_rate = 1.0 / (2.7e-3)**2

    current_time = 0.0
    total_time = 1.0

    transition_state_mat = zeros((4, no_domains))
    while current_time <= total_time and end_position <= no_domains:
        # Generate transition rate matrix.
        # Actin loading.
        transition_state_mat[0, logical_and(has_npf_row, ~has_monomer_row)] = loading_rate
        # Actin unloading.
        transition_state_mat[1, logical_and(has_npf_row, has_monomer_row)] = unloading_rate
        # Forward diffusion.
        transition_state_mat[2, :] = actin_diff_rate * monomer_count_row
        # Backward diffusion
        transition_state_mat[3, :] = actin_diff_rate * monomer_count_row
        total_rate = transition_state_mat.sum()
        #probability_row = transition_state_mat.flatten() / total_rate
        #index_transition = argpartition(1 - probability_row, 1)[1]
        #index_transition = choice(probability_row.size, p = probability_row)
        transition_cumsum = (hstack((0, transition_state_mat.flatten()))).cumsum()
        index_transition = searchsorted(transition_cumsum > total_rate * rand(), True) - 1
        transition_row, transition_col = unravel_index(index_transition, transition_state_mat.shape)
        if transition_row == 0:
            has_monomer_row[transition_col] = True
        elif transition_row == 1:
            has_monomer_row[transition_col] = False
            monomer_count_row[transition_col] += 1
        elif transition_row == 2:
            monomer_count_row[transition_col] -= 1
            if transition_col < (no_domains - 1):
                monomer_count_row[transition_col + 1] += 1
        elif transition_row == 3:
            monomer_count_row[transition_col] -= 1
            if transition_col > 0:
                monomer_count_row[transition_col - 1] += 1
        time_interval = -log(rand()) / total_rate
        current_time += time_interval
        if monomer_count_row[end_position + 1] > 0:
            monomer_count_row[end_position + 1] -= 1
            end_position += 1
        if exp(-elongation_rate * time_interval) < rand():
            end_position += 1
    print(end_position / current_time)
    return end_position / current_time

# %%
# %lprun -f simulate_polymerase simulate_polymerase()
# Out:
# 59.999993861419355
# Timer unit: 1e-06 s
#
# Total time: 187.043 s
# File: <ipython-input-1-e8d492aca994>
# Function: simulate_polymerase at line 4
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      4                                           def simulate_polymerase():
#      5         1          3.0      3.0      0.0      end_position = 0
#      6         1          5.0      5.0      0.0      no_domains = round(1.0 / (2.7e-3))
#      7         1         20.0     20.0      0.0      has_npf_row = zeros(no_domains, dtype = bool)
#      8         1         37.0     37.0      0.0      has_npf_row[arange(0, no_domains, 10)] = True
#      9         1          9.0      9.0      0.0      has_monomer_row = zeros(no_domains, dtype = bool)
#     10         1         11.0     11.0      0.0      monomer_count_row = zeros(no_domains, dtype = int)
#     11
#     12         1          2.0      2.0      0.0      actin_conc = 2.0
#     13         1          3.0      3.0      0.0      elongation_rate = 11 * actin_conc
#     14         1          2.0      2.0      0.0      loading_rate = 5.0 * actin_conc * (42 / (42 + 8))**(1/3)
#     15         1          2.0      2.0      0.0      unloading_rate = 3.0
#     16         1          3.0      3.0      0.0      actin_diff_rate = 1.0 / (2.7e-3)**2
#     17
#     18         1          2.0      2.0      0.0      current_time = 0.0
#     19         1          3.0      3.0      0.0      total_time = 1.0
#     20
#     21         1         12.0     12.0      0.0      transition_state_mat = zeros((4, no_domains))
#     22   1356159    2602189.0      1.9      1.4      while current_time <= total_time and end_position <= no_domains:
#     23                                                   # Generate transition rate matrix.
#     24                                                   # Actin loading.
#     25   1356158   12500777.0      9.2      6.7          transition_state_mat[0, logical_and(has_npf_row, ~has_monomer_row)] = loading_rate
#     26                                                   # Actin unloading.
#     27   1356158    8041117.0      5.9      4.3          transition_state_mat[1, logical_and(has_npf_row, has_monomer_row)] = unloading_rate
#     28                                                   # Forward diffusion.
#     29   1356158    9316034.0      6.9      5.0          transition_state_mat[2, :] = actin_diff_rate * monomer_count_row
#     30                                                   # Backward diffusion
#     31   1356158    6649115.0      4.9      3.6          transition_state_mat[3, :] = actin_diff_rate * monomer_count_row
#     32   1356158   14770440.0     10.9      7.9          total_rate = transition_state_mat.sum()
#     33                                                   #probability_row = transition_state_mat.flatten() / total_rate
#     34                                                   #index_transition = argpartition(1 - probability_row, 1)[1]
#     35                                                   #index_transition = choice(probability_row.size, p = probability_row)
#     36   1356158   52972596.0     39.1     28.3          transition_cumsum = (hstack((0, transition_state_mat.flatten()))).cumsum()
#     37   1356158   24651268.0     18.2     13.2          index_transition = searchsorted(transition_cumsum > total_rate * rand(), True) - 1
#     38   1356158   13385976.0      9.9      7.2          transition_row, transition_col = unravel_index(index_transition, transition_state_mat.shape)
#     39   1356158    3016127.0      2.2      1.6          if transition_row == 0:
#     40       366        938.0      2.6      0.0              has_monomer_row[transition_col] = True
#     41   1355792    2456538.0      1.8      1.3          elif transition_row == 1:
#     42        93        223.0      2.4      0.0              has_monomer_row[transition_col] = False
#     43        93        306.0      3.3      0.0              monomer_count_row[transition_col] += 1
#     44   1355699    2441867.0      1.8      1.3          elif transition_row == 2:
#     45    678195    2194966.0      3.2      1.2              monomer_count_row[transition_col] -= 1
#     46    678195    1385539.0      2.0      0.7              if transition_col < (no_domains - 1):
#     47    678154    2097520.0      3.1      1.1                  monomer_count_row[transition_col + 1] += 1
#     48    677504    1220323.0      1.8      0.7          elif transition_row == 3:
#     49    677504    2200866.0      3.2      1.2              monomer_count_row[transition_col] -= 1
#     50    677504    1246547.0      1.8      0.7              if transition_col > 0:
#     51    677502    2076207.0      3.1      1.1                  monomer_count_row[transition_col - 1] += 1
#     52   1356158    8379472.0      6.2      4.5          time_interval = -log(rand()) / total_rate
#     53   1356158    2418145.0      1.8      1.3          current_time += time_interval
#     54   1356158    3174426.0      2.3      1.7          if monomer_count_row[end_position + 1] > 0:
#     55        44        118.0      2.7      0.0              monomer_count_row[end_position + 1] -= 1
#     56        44         69.0      1.6      0.0              end_position += 1
#     57   1356158    7842484.0      5.8      4.2          if exp(-elongation_rate * time_interval) < rand():
#     58        16         48.0      3.0      0.0              end_position += 1
#     59         1        183.0    183.0      0.0      print(end_position / current_time)
#     60         1          4.0      4.0      0.0      return end_position / current_time
