# %%
from discrete_npf_assembly import *

# %%
actin_network = network()

# %%
actin_network.update_proximal_end_index()
actin_network.update_nearest_end_index()
# Out:
# [29. nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
# [ 29. 160.  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan]
# [ 29. 160.  74.  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan]
# [ 29. 160.  74. 152.  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan]
# ...

# %%
print(actin_network.index_nearest_end_row)
# Out:
# [ 29. 160.  74. 152.  49.  24.  97. 188. 141.  93. 137. 174. 125.  87.
#   14.  85. 142.  12.  72. 140.  90. 111.  83. 118. 163.  38. 183. 169.
#  189. 186.  75.  83.  66. 142.  66. 183.  25.  33.  59. 142. 157. 178.
#  131. 107.  39.  21.  48. 133.  24. 155.]
