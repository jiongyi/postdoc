# %%
from puncta_quantification import *

# %%
axes1_obj, wta_6hr_post0gr_data = plot_quantification(compile_csv_files('/home/jiongyi/Documents/dna_damage/immunofluorescence/2019_01_13/6hr_wt_a_happy/'))
axes2_obj, wta_6hr_post2gr_data = plot_quantification(compile_csv_files('/home/jiongyi/Documents/dna_damage/immunofluorescence/2019_01_13/6hr_wt_a_sad/'))
axes3_obj, wta_24hr_post0gr_data = plot_quantification(compile_csv_files('/home/jiongyi/Documents/dna_damage/immunofluorescence/2019_01_13/24hr_wt_a_happy'))
axes4_obj, wta_24hr_post2gr_data = plot_quantification(compile_csv_files('/home/jiongyi/Documents/dna_damage/immunofluorescence/2019_01_13/24hr_wt_a_sad/'))

# %%
from matplotlib.pyplot import subplots
from numpy import linspace, median, std, concatenate
a_row = wta_6hr_post0gr_data.get('pH2AX').values
b_row = wta_6hr_post2gr_data.get('pH2AX').values
x_row = linspace(0, max(concatenate((a_row, b_row))), 100)
fig_obj, axes_obj = subplots()
axes_obj.hist(a_row, bins = x_row, cumulative = True, histtype = 'step', density = True, color = 'b')
axes_obj.hist(b_row, bins = x_row, cumulative = True, histtype = 'step', density = True, color = 'r')
print(median(a_row))
print(bootstrap_median(a_row))
print(median(b_row))
print(bootstrap_median(b_row))
# Out:
# 0.6414886159852293
# 0.281347191124467
# 1.7132401144894633
# 0.2805887438823743

# %%
a_row = wta_6hr_post0gr_data.get('53BP1').values
b_row = wta_6hr_post2gr_data.get('53BP1').values
x_row = linspace(0, max(concatenate((a_row, b_row))), 100)
fig_obj, axes_obj = subplots()
axes_obj.hist(a_row, bins = x_row, cumulative = True, histtype = 'step', density = True, color = 'b')
axes_obj.hist(b_row, bins = x_row, cumulative = True, histtype = 'step', density = True, color = 'r')
print(median(a_row))
print(bootstrap_median(a_row))
print(median(b_row))
print(bootstrap_median(b_row))
# Out:
# 0.4325819526237866
# 0.31576292363480885
# 2.147670665949078
# 0.7372026954343736

# %%
a_row = wta_24hr_post0gr_data.get('pH2AX').values
b_row = wta_24hr_post2gr_data.get('pH2AX').values
x_row = linspace(0, max(concatenate((a_row, b_row))), 100)
fig_obj, axes_obj = subplots()
axes_obj.hist(a_row, bins = x_row, cumulative = True, histtype = 'step', density = True, color = 'b')
axes_obj.hist(b_row, bins = x_row, cumulative = True, histtype = 'step', density = True, color = 'r')
print(median(a_row))
print(bootstrap_median(a_row))
print(median(b_row))
print(bootstrap_median(b_row))
# Out:
# 0.47177478053103805
# 0.12132147744888154
# 0.470817286237788
# 0.12093693031310679

# %%
a_row = wta_24hr_post0gr_data.get('53BP1').values
b_row = wta_24hr_post2gr_data.get('53BP1').values
x_row = linspace(0, max(concatenate((a_row, b_row))), 100)
fig_obj, axes_obj = subplots()
axes_obj.hist(a_row, bins = x_row, cumulative = True, histtype = 'step', density = True, color = 'b')
axes_obj.hist(b_row, bins = x_row, cumulative = True, histtype = 'step', density = True, color = 'r')
print(median(a_row))
print(bootstrap_median(a_row))
print(median(b_row))
print(bootstrap_median(b_row))
# Out:
# 0.8093849495901992
# 0.22395853803027116
# 4.007255463409407
# 1.0106711813857088
