# %%
from puncta_quantification import *

# %%
wt_a_ir_post_30m_data_folder = '/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_28/u2os_wt_30_m_post_2gr_pH2AX_53pb1_dapi_b'
wt_a_ctrl_post_60m_data_folder = '/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_28/u2os_wt_60_m_post_0gr_pH2AX_53pb1_dapi_a'
wt_a_ir_post_60m_data_folder = '/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_28/u2os_wt_60_m_post_2gr_pH2AX_53pb1_dapi_a'
ipo9kd_a_ctrl_post_30m_data_folder = '/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_28/u2os_ipo9_kd_30_m_post_0gr_pH2AX_53pb1_dapi_a'
ipo9kd_a_ir_post_60m_data_folder = '/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_28/u2os_ipo9_kd_60_m_post_2gr_pH2AX_53pb1_dapi_a'
fmn2kd_a_ctrl_post_60m_data_folder = '/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_29/u2os_fmn2_kd_60_m_post_0gr_dapi_gh2ax_53bp1_a'
fmn2kd_a_ir_post_60m_data_folder = '/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_29/u2os_fmn2_kd_60_m_post_2gr_dapi_gh2ax_53bp1_a'
wt_b_ir_post_60m_data_folder = '/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_29/u2os_wt_60_m_post_2gr_dapi_gh2ax_53bp1_b'
wt_a_ctrl_post_360m_data_folder = '/home/jiongyi/Documents/dna_damage/immunofluorescence/2019_01_13/6hr_wt_a_happy'
wt_a_ir_post_360m_data_folder = '/home/jiongyi/Documents/dna_damage/immunofluorescence/2019_01_13/6hr_wt_a_sad'
wt_a_ctrl_post_1440m_data_folder = '/home/jiongyi/Documents/dna_damage/immunofluorescence/2019_01_13/24hr_wt_a_happy'
wt_a_ir_post_1440m_data_folder = '/home/jiongyi/Documents/dna_damage/immunofluorescence/2019_01_13/24hr_wt_a_sad'
ipo9kd_a_ctrl_post_360m_data_folder = '/home/jiongyi/Documents/dna_damage/immunofluorescence/2019_01_14/6hr_ipo9_kd_a_happy'
ipo9kd_a_ir_post_360m_data_folder = '/home/jiongyi/Documents/dna_damage/immunofluorescence/2019_01_14/6hr_ipo9_kd_a_sad'
ipo9kd_a_ctrl_post_1440m_data_folder = '/home/jiongyi/Documents/dna_damage/immunofluorescence/2019_01_14/24hr_ipo9_kd_a_happy'
ipo9kd_a_ir_post_1440m_data_folder = '/home/jiongyi/Documents/dna_damage/immunofluorescence/2019_01_14/24hr_ipo9_kd_sad'

# %%
batch_get_regionprops('/home/jiongyi/Documents/dna_damage/immunofluorescence/2019_01_14')
# Out:
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:141: UserWarning: Possible precision loss when converting from uint16 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:141: UserWarning: Possible precision loss when converting from uint16 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:141: UserWarning: Possible precision loss when converting from uint16 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:141: UserWarning: Possible precision loss when converting from uint16 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:141: UserWarning: Possible precision loss when converting from uint16 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# ...

# %%
# Irradiated wild type U2OS cells.
wt_a_ir_post_30m_df = batch_aggregate_data(wt_a_ir_post_30m_data_folder)
wt_a_ir_post_60m_df = batch_aggregate_data(wt_a_ir_post_60m_data_folder)
wt_a_ir_post_360m_df = batch_aggregate_data(wt_a_ir_post_360m_data_folder)
wt_a_ir_post_1440m_df = batch_aggregate_data(wt_a_ir_post_1440m_data_folder)
# Control U2OS cells.
wt_a_ctrl_post_60m_df = batch_aggregate_data(wt_a_ctrl_post_60m_data_folder)
wt_a_ctrl_post_360m_df = batch_aggregate_data(wt_a_ctrl_post_360m_data_folder)
wt_a_ctrl_post_1440m_df = batch_aggregate_data(wt_a_ctrl_post_1440m_data_folder)
# FMN2KD cells.
fmn2kd_a_ctrl_post_60m_df = batch_aggregate_data(fmn2kd_a_ctrl_post_60m_data_folder)
fmn2kd_a_ir_post_60m_df = batch_aggregate_data(fmn2kd_a_ir_post_60m_data_folder)
# IPO9KD cells.
ipo9kd_a_ctrl_post_30m_df = batch_aggregate_data(ipo9kd_a_ctrl_post_30m_data_folder)
ipo9kd_a_ir_post_60m_df = batch_aggregate_data(ipo9kd_a_ir_post_60m_data_folder)
ipo9kd_a_ctrl_post_360m_df = batch_aggregate_data(ipo9kd_a_ctrl_post_360m_data_folder)
ipo9kd_a_ir_post_360m_df = batch_aggregate_data(ipo9kd_a_ir_post_360m_data_folder)
ipo9kd_a_ctrl_post_1440m_df = batch_aggregate_data(ipo9kd_a_ctrl_post_1440m_data_folder)
ipo9kd_a_ir_post_1440m_df = batch_aggregate_data(ipo9kd_a_ir_post_1440m_data_folder)

# %%
from matplotlib.pyplot import subplots, errorbar
from numpy import abs
# Plot boxplot statistics.
wt_a_ir_median_ph2ax_row = zeros(4)
wt_a_ir_ph2ax_quartile_mat = zeros((4, 2))
wt_a_ir_median_dna_rp_row = zeros(4)
wt_a_ir_dna_rp_quartile_mat = zeros((4, 2))
wt_a_ir_median_ph2ax_row[0], wt_a_ir_ph2ax_quartile_mat[0, :], wt_a_ir_median_dna_rp_row[0], wt_a_ir_dna_rp_quartile_mat[0, :] = compute_boxplot_statistics(wt_a_ir_post_30m_df)
wt_a_ir_median_ph2ax_row[1], wt_a_ir_ph2ax_quartile_mat[1, :], wt_a_ir_median_dna_rp_row[1], wt_a_ir_dna_rp_quartile_mat[1, :] = compute_boxplot_statistics(wt_a_ir_post_60m_df)
wt_a_ir_median_ph2ax_row[2], wt_a_ir_ph2ax_quartile_mat[2, :], wt_a_ir_median_dna_rp_row[2], wt_a_ir_dna_rp_quartile_mat[2, :] = compute_boxplot_statistics(wt_a_ir_post_360m_df)
wt_a_ir_median_ph2ax_row[3], wt_a_ir_ph2ax_quartile_mat[3, :], wt_a_ir_median_dna_rp_row[3], wt_a_ir_dna_rp_quartile_mat[3, :] = compute_boxplot_statistics(wt_a_ir_post_1440m_df)

wt_a_ctrl_median_ph2ax_row = zeros(3)
wt_a_ctrl_ph2ax_quartile_mat = zeros((3, 2))
wt_a_ctrl_median_dna_rp_row = zeros(3)
wt_a_ctrl_dna_rp_quartile_mat = zeros((3, 2))
wt_a_ctrl_median_ph2ax_row[0], wt_a_ctrl_ph2ax_quartile_mat[0, :], wt_a_ctrl_median_dna_rp_row[0], wt_a_ctrl_dna_rp_quartile_mat[0, :] = compute_boxplot_statistics(wt_a_ctrl_post_60m_df)
wt_a_ctrl_median_ph2ax_row[1], wt_a_ctrl_ph2ax_quartile_mat[1, :], wt_a_ctrl_median_dna_rp_row[1], wt_a_ctrl_dna_rp_quartile_mat[1, :] = compute_boxplot_statistics(wt_a_ctrl_post_360m_df)
wt_a_ctrl_median_ph2ax_row[2], wt_a_ctrl_ph2ax_quartile_mat[2, :], wt_a_ctrl_median_dna_rp_row[2], wt_a_ctrl_dna_rp_quartile_mat[2, :] = compute_boxplot_statistics(wt_a_ctrl_post_1440m_df)

figure_handle, axes_handle = subplots()
figure_handle.set_figwidth(5)
axes_handle.errorbar(array([1, 6, 24]), wt_a_ctrl_median_ph2ax_row, yerr = abs(wt_a_ctrl_ph2ax_quartile_mat.transpose() - wt_a_ctrl_median_ph2ax_row), marker = "o")
axes_handle.errorbar(array([0.5, 1, 6, 24]), wt_a_ir_median_ph2ax_row, yerr = abs(wt_a_ir_ph2ax_quartile_mat.transpose() - wt_a_ir_median_ph2ax_row), marker = "o")
axes_handle.tick_params(labelsize = 14)
axes_handle.set_xlabel('Recovery time (hr)', fontsize = 14)
axes_handle.set_ylabel('Median pH2AX flux (AU)', fontsize = 14)
axes_handle.legend(['0 Gy', '2 Gy'], fontsize = 14)

# %%
figure_handle, axes_handle = subplots()
figure_handle.set_figwidth(5)
axes_handle.errorbar(array([1, 6, 24]), wt_a_ctrl_median_dna_rp_row, yerr = abs(wt_a_ctrl_dna_rp_quartile_mat.transpose() - wt_a_ctrl_median_dna_rp_row), marker = "o")
axes_handle.errorbar(array([0.5, 1, 6, 24]), wt_a_ir_median_dna_rp_row, yerr = abs(wt_a_ir_dna_rp_quartile_mat.transpose() - wt_a_ir_median_dna_rp_row), marker = "o")
axes_handle.tick_params(labelsize = 14)
axes_handle.set_xlabel('Recovery time (hr)', fontsize = 14)
axes_handle.set_ylabel('Median 53BP1 flux (AU)', fontsize = 14)
axes_handle.legend(['0 Gy', '2 Gy'], fontsize = 14)

# %%
ipo9kd_a_ir_median_ph2ax_row = zeros(3)
ipo9kd_a_ir_ph2ax_quartile_mat = zeros((3, 2))
ipo9kd_a_ir_median_dna_rp_row = zeros(3)
ipo9kd_a_ir_dna_rp_quartile_mat = zeros((3, 2))

ipo9kd_a_ctrl_median_ph2ax_row = zeros(3)
ipo9kd_a_ctrl_ph2ax_quartile_mat = zeros((3, 2))
ipo9kd_a_ctrl_median_dna_rp_row = zeros(3)
ipo9kd_a_ctrl_dna_rp_quartile_mat = zeros((3, 2))

ipo9kd_a_ir_median_ph2ax_row[0], ipo9kd_a_ir_ph2ax_quartile_mat[0, :], ipo9kd_a_ir_median_dna_rp_row[0], ipo9kd_a_ir_dna_rp_quartile_mat[0, :] = compute_boxplot_statistics(ipo9kd_a_ir_post_60m_df)
ipo9kd_a_ir_median_ph2ax_row[1], ipo9kd_a_ir_ph2ax_quartile_mat[1, :], ipo9kd_a_ir_median_dna_rp_row[1], ipo9kd_a_ir_dna_rp_quartile_mat[1, :] = compute_boxplot_statistics(ipo9kd_a_ir_post_360m_df)
ipo9kd_a_ir_median_ph2ax_row[2], ipo9kd_a_ir_ph2ax_quartile_mat[2, :], ipo9kd_a_ir_median_dna_rp_row[2], ipo9kd_a_ir_dna_rp_quartile_mat[2, :] = compute_boxplot_statistics(ipo9kd_a_ir_post_1440m_df)

ipo9kd_a_ctrl_median_ph2ax_row[0], ipo9kd_a_ctrl_ph2ax_quartile_mat[0, :], ipo9kd_a_ctrl_median_dna_rp_row[0], ipo9kd_a_ctrl_dna_rp_quartile_mat[0, :] = compute_boxplot_statistics(ipo9kd_a_ctrl_post_30m_df)
ipo9kd_a_ctrl_median_ph2ax_row[1], ipo9kd_a_ctrl_ph2ax_quartile_mat[1, :], ipo9kd_a_ctrl_median_dna_rp_row[1], ipo9kd_a_ctrl_dna_rp_quartile_mat[1, :] = compute_boxplot_statistics(ipo9kd_a_ctrl_post_360m_df)
ipo9kd_a_ctrl_median_ph2ax_row[2], ipo9kd_a_ctrl_ph2ax_quartile_mat[2, :], ipo9kd_a_ctrl_median_dna_rp_row[2], ipo9kd_a_ctrl_dna_rp_quartile_mat[2, :] = compute_boxplot_statistics(ipo9kd_a_ctrl_post_1440m_df)

figure_handle, axes_handle = subplots()
figure_handle.set_figwidth(5)
axes_handle.errorbar(array([0.5, 6, 24]), ipo9kd_a_ctrl_median_ph2ax_row, yerr = abs(ipo9kd_a_ctrl_ph2ax_quartile_mat.transpose() - ipo9kd_a_ctrl_median_ph2ax_row), marker = "o")
axes_handle.errorbar(array([1, 6, 24]), ipo9kd_a_ir_median_ph2ax_row, yerr = abs(ipo9kd_a_ir_ph2ax_quartile_mat.transpose() - ipo9kd_a_ir_median_ph2ax_row), marker = "o")
axes_handle.set_xlabel('Recovery time (hr)', fontsize = 14)
axes_handle.set_ylabel('Median pH2AX flux (AU)', fontsize = 14)
axes_handle.legend(['0 Gy', '2 Gy'], fontsize = 14)

# %%
figure_handle, axes_handle = subplots()
figure_handle.set_figwidth(5)
axes_handle.errorbar(array([0.5, 6, 24]), ipo9kd_a_ctrl_median_dna_rp_row, yerr = abs(ipo9kd_a_ctrl_dna_rp_quartile_mat.transpose() - ipo9kd_a_ctrl_median_dna_rp_row), marker = "o")
axes_handle.errorbar(array([1, 6, 24]), ipo9kd_a_ir_median_dna_rp_row, yerr = abs(ipo9kd_a_ir_dna_rp_quartile_mat.transpose() - ipo9kd_a_ir_median_dna_rp_row), marker = "o")
axes_handle.tick_params(labelsize = 14)
axes_handle.set_xlabel('Recovery time (hr)', fontsize = 14)
axes_handle.set_ylabel('Median 53BP1 flux (AU)', fontsize = 14)
axes_handle.legend(['0 Gy', '2 Gy'], fontsize = 14)

# %%
fmn2kd_a_ir_median_ph2ax, fmn2kd_a_ir_ph2ax_quartile_mat, fmn2kd_a_ir_median_dna_rp, fmn2kd_a_ir_dna_rp_quartile_mat = compute_boxplot_statistics(fmn2kd_a_ir_post_60m_df)
fmn2kd_a_ctrl_median_ph2ax, fmn2kd_a_ctrl_ph2ax_quartile_mat, fmn2kd_a_ctrl_median_dna_rp, fmn2kd_a_ctrl_dna_rp_quartile_mat = compute_boxplot_statistics(fmn2kd_a_ctrl_post_60m_df)

# %%
compare_dna_rp_flux_density(wt_a_ir_post_60m_df, 'WT', fmn2kd_a_ir_post_60m_df, 'FMN2 KD')
# Out:
# Mean A:4.479710835221199
# Stdev A:4.000081152309823
# Mean B:5.278336307892046
# Stdev B:4.372890502433704
