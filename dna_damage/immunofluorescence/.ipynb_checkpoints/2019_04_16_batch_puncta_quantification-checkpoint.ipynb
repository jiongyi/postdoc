# %%
from standard_fluorescence_intensity import *

# %%
arp3_folder_name = '/home/jiongyi/Documents/dna_damage/immunofluorescence/2019_04_12/arp3'
dna_pk_cs_folder_name = '/home/jiongyi/Documents/dna_damage/immunofluorescence/2019_04_12/dna_pk_cs'
rpa2_folder_name = '/home/jiongyi/Documents/dna_damage/immunofluorescence/2019_04_12/rpa2'
no_blc_arp3_flux_row = batch_get_dna_rp_regionprops(arp3_folder_name + '/no_blc')
plus_blc_arp3_flux_row = batch_get_dna_rp_regionprops(arp3_folder_name + '/5_ug_mL_blc')
no_blc_dna_pk_cs_flux_row = batch_get_dna_rp_regionprops(dna_pk_cs_folder_name + '/no_blc')
plus_blc_dna_pk_cs_flux_row = batch_get_dna_rp_regionprops(dna_pk_cs_folder_name + '/5_ug_mL_blc')
no_blc_rpa2_flux_row = batch_get_dna_rp_regionprops(rpa2_folder_name + '/no_blc')
plus_blc_rpa2_flux_row = batch_get_dna_rp_regionprops(rpa2_folder_name + '/5_ug_mL_blc')

# %%
# %matplotlib inline
from pandas import DataFrame
from seaborn import swarmplot
arp3_frame = DataFrame.from_dict(data = {'0 ug/mL': no_blc_arp3_flux_row, '5 ug/mL': plus_blc_arp3_flux_row}, orient = 'index')
swarmplot(data = arp3_frame.transpose())

# %%
dna_pk_cs_frame = DataFrame.from_dict(data = {'0 ug/mL': no_blc_dna_pk_cs_flux_row, '5 ug/mL': plus_blc_dna_pk_cs_flux_row}, orient = 'index')
swarmplot(data = dna_pk_cs_frame.transpose())

# %%
rpa2_frame = DataFrame.from_dict(data = {'0 ug/mL': no_blc_rpa2_flux_row, '5 ug/mL': plus_blc_rpa2_flux_row}, orient = 'index')
swarmplot(data = rpa2_frame.transpose())
