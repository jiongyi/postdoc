# %%
from puncta_quantification import *

# %%
fmn2kd_dnapkcs_df = batch_aggregate_data('/home/jiongyi/Documents/dna_damage/immunofluorescence/knock_down/formin_2/2_gamma/DNA PKcs')
fmn2kd_mdc1_df = batch_aggregate_data('/home/jiongyi/Documents/dna_damage/immunofluorescence/knock_down/formin_2/2_gamma/Mdc1')
fmn2kd_atm_df = batch_aggregate_data('/home/jiongyi/Documents/dna_damage/immunofluorescence/knock_down/formin_2/2_gamma/pATM')
fmn2kd_rad51_df = batch_aggregate_data('/home/jiongyi/Documents/dna_damage/immunofluorescence/knock_down/formin_2/2_gamma/Rad51')
wt_arp3_df = batch_aggregate_data('/home/jiongyi/Documents/dna_damage/immunofluorescence/wildtype/2_gamma/Arp3 WT 2g 1hr postIR')
wt_atm_df = batch_aggregate_data('/home/jiongyi/Documents/dna_damage/immunofluorescence/wildtype/2_gamma/WT ATM 2g 1hr postIR')
wt_dnapkcs_df = batch_aggregate_data('/home/jiongyi/Documents/dna_damage/immunofluorescence/wildtype/2_gamma/WT DNA PKcs 1hr postIR')
wt_ku80_df = batch_aggregate_data('/home/jiongyi/Documents/dna_damage/immunofluorescence/wildtype/2_gamma/WT Ku80 2g 1hr postIR')
wt_rad51_df = batch_aggregate_data('/home/jiongyi/Documents/dna_damage/immunofluorescence/wildtype/2_gamma/WT Rad51 2g 1hr postIR')
wt_rpa32_df = batch_aggregate_data('/home/jiongyi/Documents/dna_damage/immunofluorescence/wildtype/2_gamma/WT Rad51 2g 1hr postIR')

# %%
compare_ph2ax_flux_density(wt_rad51_df, 'WT', fmn2kd_rad51_df, 'FMN2 KD')
# Out:
# Mean A:6.043133531589354
# Stdev A:5.064094617746411
# Mean B:2.8819212172129074
# Stdev B:2.3234805371032214

# %%
compare_dna_rp_flux_density(wt_rad51_df, 'WT', fmn2kd_rad51_df, 'FMN2 KD')
# Out:
# Mean A:0.6631585211636398
# Stdev A:0.8050500071064581
# Mean B:0.08331724573154488
# Stdev B:0.11510547199367396

# %%
compare_repair_positive_flux(wt_dnapkcs_df, 'WT', fmn2kd_dnapkcs_df, 'FMN2KD')
