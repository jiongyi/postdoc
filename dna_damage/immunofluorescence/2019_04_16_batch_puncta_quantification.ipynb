# %%
from puncta_quantification import *

# %%
post_0gr_data_folder = '/home/jiongyi/Documents/dna_damage/u2os_wt_60_m_post_0gr_pH2AX_53pb1_dapi_a'
post_2gr_data_folder = '/home/jiongyi/Documents/dna_damage/u2os_wt_60_m_post_2gr_pH2AX_53pb1_dapi_a'

# %%
post_0gr_df = batch_aggregate_data(post_0gr_data_folder)
post_2gr_df = batch_aggregate_data(post_2gr_data_folder)

# %%
compare_dna_rp_flux_density(post_0gr_df, '0 Gy', post_2gr_df, '2 Gy')

# %%
compare_ph2ax_flux_density(post_0gr_df, '0 Gy', post_2gr_df, '2 Gy')

# %%
compare_repair_positive_flux(post_0gr_df, '0 Gy', post_2gr_df, '2 Gy')
