# %%
from puncta_quantification import *

# %%
batch_quantification('/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_28/u2os_wt_30_m_post_2gr_pH2AX_53pb1_dapi_b')
batch_quantification('/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_28/u2os_wt_60_m_post_0gr_pH2AX_53pb1_dapi_a')
batch_quantification('/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_28/u2os_wt_60_m_post_2gr_pH2AX_53pb1_dapi_a')
batch_quantification('/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_29/u2os_wt_60_m_post_2gr_dapi_gh2ax_53bp1_b')
batch_quantification('/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_28/u2os_ipo9_kd_60_m_post_2gr_pH2AX_53pb1_dapi_a')
# Out:
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:110: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/jiongyi/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ...

# %%
axes1_obj = plot_quantification(compile_csv_files('/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_28/u2os_wt_30_m_post_2gr_pH2AX_53pb1_dapi_b'))
axes2_obj = plot_quantification(compile_csv_files('/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_28/u2os_wt_60_m_post_0gr_pH2AX_53pb1_dapi_a'))
axes3_obj = plot_quantification(compile_csv_files('/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_28/u2os_wt_60_m_post_2gr_pH2AX_53pb1_dapi_a'))
axes4_obj = plot_quantification(compile_csv_files('/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_29/u2os_wt_60_m_post_2gr_dapi_gh2ax_53bp1_b'))
axes5_obj = plot_quantification(compile_csv_files('/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_28/u2os_ipo9_kd_60_m_post_2gr_pH2AX_53pb1_dapi_a'))
axes1_obj[0].set_ylim([0, 50])
axes2_obj[0].set_ylim([0, 50])
axes3_obj[0].set_ylim([0, 50])
axes4_obj[0].set_ylim([0, 50])
axes5_obj[0].set_ylim([0, 50])
# Out:
# (0, 50)
