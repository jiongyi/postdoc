# %%
from puncta_quantification import *

# %%
wtb_30m_post_2gr_csv_dict = compile_csv_files('/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_28/u2os_wt_30_m_post_2gr_pH2AX_53pb1_dapi_b')
wta_60m_post_0gr_csv_dict = compile_csv_files('/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_28/u2os_wt_60_m_post_0gr_pH2AX_53pb1_dapi_a')
wta_60m_post_2gr_csv_dict = compile_csv_files('/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_28/u2os_wt_60_m_post_2gr_pH2AX_53pb1_dapi_a')
wtb_60m_post_2gr_csv_dict = compile_csv_files('/home/jiongyi/Documents/dna_damage/immunofluorescence/2018_12_29/u2os_wt_60_m_post_2gr_dapi_gh2ax_53bp1_b')

# %%
axes1_obj, data1_frame = plot_quantification(wta_60m_post_0gr_csv_dict)
axes2_obj, data2_frame = plot_quantification(wtb_30m_post_2gr_csv_dict)
axes3_obj, data3_frame = plot_quantification(wta_60m_post_2gr_csv_dict)
axes4_obj, data4_frame = plot_quantification(wtb_60m_post_2gr_csv_dict)

# %%
untreated_ph2ax_row = data1_frame.get('pH2AX').values
untreated_53bp1_row = data1_frame.get('53BP1').values
treated_ph2ax_row = data4_frame.get('pH2AX').values
treated_53bp1_row = data4_frame.get('53BP1').values
swarmplot(data = [untreated_ph2ax_row.transpose(), treated_ph2ax_row.transpose()])

# %%
swarmplot(data = [untreated_53bp1_row.transpose(), treated_53bp1_row.transpose()])
